# %%
import pandas as pd

# %%
from pycoingecko import CoinGeckoAPI
gk = CoinGeckoAPI()

# %%
r = gk.get_coins_list()

# %%
tdf = pd.DataFrame(r)

# %%
tdf.loc[tdf['id']=='dogecoin', 'symbol']
# Out:
# 2609    doge
# Name: symbol, dtype: object

# %%
gk.search('doge')
# Out:
# {'coins': [{'id': 'dogecoin',
#    'name': 'Dogecoin',
#    'api_symbol': 'dogecoin',
#    'symbol': 'DOGE',
#    'market_cap_rank': 10,
#    'thumb': 'https://assets.coingecko.com/coins/images/5/thumb/dogecoin.png',
#    'large': 'https://assets.coingecko.com/coins/images/5/large/dogecoin.png'},
#   {'id': 'baby-doge-coin',
#    'name': 'Baby Doge Coin',
#    'api_symbol': 'baby-doge-coin',
#    'symbol': 'BABYDOGE',
#    'market_cap_rank': 169,
#    'thumb': 'https://assets.coingecko.com/coins/images/16125/thumb/babydoge.jpg',
#    'large': 'https://assets.coingecko.com/coins/images/16125/large/babydoge.jpg'},
#   {'id': 'dogelon-mars',
#    'name': 'Dogelon Mars',
#    'api_symbol': 'dogelon-mars',
#    'symbol': 'ELON',
#    'market_cap_rank': 281,
#    'thumb': 'https://assets.coingecko.com/coins/images/14962/thumb/6GxcPRo3_400x400.jpg',
#    'large': 'https://assets.coingecko.com/coins/images/14962/large/6GxcPRo3_400x400.jpg'},
#   {'id': 'leash',
#    'name': 'Doge Killer',
# ...
